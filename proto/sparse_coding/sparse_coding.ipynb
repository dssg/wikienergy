# %%
import pandas as pd
import numpy as np

#query data by id and categorize it
categories = ['hvac', 'refrigerator', 'waterheater', 'inside_lights', 'outside_lights', 'livingroom', 'kitchen', 'washer_dryer', 'misc'];
category_map = {
'use': ['use'],
'hvac': ['air1','air2','air3','airwindowunit1','furnace1','furnace2','heater1','housefan1'],
'refrigerator': ['refrigerator1','refrigerator2','freezer1'],
'waterheater': ['waterheater1','waterheater2'],
'livingroom': ['livingroom1','livingroom2'],
'inside_lights': ['bedroom1','bedroom2','bedroom3','bedroom4','bedroom5','bathroom1','diningroom1','diningroom2','lights_plugs1','lights_plugs2','lights_plugs3','lights_plugs4','lights_plugs5','lights_plugs6', ],
'outside_lights': ['outsidelights_plugs1','outsidelights_plugs2'],
'kitchen': ['kitchen1','kitchen2','kitchenapp1','kitchenapp2','oven1','oven2','disposal1','icemaker1','microwave1','dishwasher1','range1','venthood1','winecooler1'],
'washer_dryer': ['clotheswasher1','clotheswasher_dryg1', 'drye1','dryg1'],
'misc': ['unknown1','unknown2','unknown3','unknown4','aquarium1','car1','garage1','garage2','jacuzzi1','office1','pool1','pool2','poollight1','poolpump1','pump1','security1','shed1','sprinkler1','subpanel1','subpanel2','utilityroom1']}

def categorize_data(df):
    categorized = {}
    for category,columns in category_map.iteritems():
        categorized[category] = np.zeros(24*4*1)
        for column in columns:
            categorized[category] += df[column].astype(float)
    return categorized

def read_pecan_street_sets(path, week=False):
    days = (7 if week else 1)
    curated_data = pd.read_csv(path, parse_dates=[2], nrows=4*24*days*1000).fillna(value=0)
    sets = []
    by_dataid = curated_data.groupby('dataid')
    for data_id,house_data in by_dataid:
        house_data = house_data.set_index('utc_15min')
        by_time = house_data.groupby(lambda x: x.day)
        for time, time_data in by_time:
            if len(time_data) == 24*4*days:
                sets.append(categorize_data(time_data))
    return sets

# organize 
def get_training_data(sets):
    training_data = {}
    for category in categories:
        c = []
        for set in sets:
            c.append(set[category])
        training_data[category] = np.array(c)
    return training_data

# use scikit to learn a dictionary in which the data is sparse
def learn_dictionary(training_data, n_atoms=20):
    from sklearn.decomposition import DictionaryLearning
    category_dico = {}
    for category in categories:
        dico = DictionaryLearning(n_atoms)
        dico.fit(training_data[category])
        category_dico[category] = dico.components_
    return np.concatenate(category_dico.values())

def get_sparse_coder(training_data):
    from sklearn.decomposition import SparseCoder
    dictionary = learn_dictionary(training_data)
    return SparseCoder(dictionary=dictionary)

def disaggregate(sparse_coder, series, n_atoms=20):
    set = {}
    dictionary = sparse_coder.components_
    A = sparse_coder.transform(series)
    n_atoms = len(dictionary)/len(categories)
    use = np.zeros(len(series))
    for i,category in enumerate(categories):
        sum = np.zeros(len(series))
        for j in range(n_atoms):
            k = n_atoms*i + j
            sum += A[k]*dictionary[k]
        set[category] = sum
        use += sum
    set['use'] = use
    return set

# %%
pecan_sets = read_pecan_street_sets('/home/eric/g1.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-168-6ed927beeef8> in <module>()
# ----> 1 pecan_sets = read_pecan_street_sets('/home/eric/g1.csv')
#
# <ipython-input-165-a24ad7ec4100> in read_pecan_street_sets(path, week)
#      26 def read_pecan_street_sets(path, week=False):
#      27     days = (7 if week else 1)
# ---> 28     curated_data = pd.read_csv(path, parse_dates=[2], nrows=4*24*days*1000).fillna(value=0)
#      29     sets = []
#      30     by_dataid = curated_data.groupby('dataid')
#
# /usr/lib/pymodules/python2.7/pandas/io/parsers.pyc in read_csv(filepath_or_buffer, sep, dialect, header, index_col, names, skiprows, na_values, thousands, comment, parse_dates, keep_date_col, dayfirst, date_parser, nrows, iterator, chunksize, skip_footer, converters, verbose, delimiter, encoding, squeeze)
#     234         kwds['delimiter'] = sep
#     235
# --> 236     return _read(TextParser, filepath_or_buffer, kwds)
#     237
#     238 @Appender(_read_table_doc)
#
# /usr/lib/pymodules/python2.7/pandas/io/parsers.pyc in _read(cls, filepath_or_buffer, kwds)
#     185
#     186     if nrows is not None:
# --> 187         return parser.get_chunk(nrows)
#     188     elif chunksize or iterator:
#     189         return parser
#
# /usr/lib/pymodules/python2.7/pandas/io/parsers.pyc in get_chunk(self, rows)
#     788         columns = list(self.columns)
#     789         if self.parse_dates is not None:
# --> 790             data, columns = self._process_date_conversion(data)
#     791
#     792         data = _convert_to_ndarrays(data, self.na_values, self.verbose)
#
# /usr/lib/pymodules/python2.7/pandas/io/parsers.pyc in _process_date_conversion(self, data_dict)
#     939                     if self._isindex(colspec):
#     940                         continue
# --> 941                     data_dict[colspec] = self._conv_date(data_dict[colspec])
#     942                 else:
#     943                     new_name, col, old_names = _try_convert_dates(
#
# /usr/lib/pymodules/python2.7/pandas/io/parsers.pyc in _conv_date(self, *date_cols)
#     910         if self.date_parser is None:
#     911             return lib.try_parse_dates(_concat_date_cols(date_cols),
# --> 912                                        dayfirst=self.dayfirst)
#     913         else:
#     914             try:
#
# /usr/lib/pymodules/python2.7/pandas/lib.so in pandas.lib.try_parse_dates (pandas/src/tseries.c:94208)()
#
# /usr/lib/pymodules/python2.7/pandas/lib.so in pandas.lib.try_parse_dates.lambda4 (pandas/src/tseries.c:93818)()
#
# /usr/lib/python2.7/dist-packages/dateutil/parser.pyc in parse(timestr, parserinfo, **kwargs)
#     695         return parser(parserinfo).parse(timestr, **kwargs)
#     696     else:
# --> 697         return DEFAULTPARSER.parse(timestr, **kwargs)
#     698
#     699
#
# /usr/lib/python2.7/dist-packages/dateutil/parser.pyc in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     297                     **kwargs):
#     298         if not default:
# --> 299             default = datetime.datetime.now().replace(hour=0, minute=0,
#     300                                                       second=0, microsecond=0)
#     301         res = self._parse(timestr, **kwargs)
#
# KeyboardInterrupt:

# %%
training_data = get_training_data(pecan_sets)

# %%
sparse_coder = get_sparse_coder(training_data)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-167-94d2d3a5240f> in <module>()
# ----> 1 sparse_coder = get_sparse_coder(training_data)
#
# <ipython-input-165-a24ad7ec4100> in get_sparse_coder(training_data)
#      59 def get_sparse_coder(training_data):
#      60     from sklearn.decomposition import SparseCoder
# ---> 61     dictionary = learn_dictionary(training_data)
#      62     return SparseCoder(dictionary=dictionary)
#      63
#
# <ipython-input-165-a24ad7ec4100> in learn_dictionary(training_data, n_atoms)
#      53     for category in categories:
#      54         dico = DictionaryLearning(n_atoms)
# ---> 55         dico.fit(training_data[category])
#      56         category_dico[category] = dico.components_
#      57     return np.concatenate(category_dico.values())
#
# /usr/lib/pymodules/python2.7/sklearn/decomposition/dict_learning.pyc in fit(self, X, y)
#     974                                 dict_init=self.dict_init,
#     975                                 verbose=self.verbose,
# --> 976                                 random_state=self.random_state)
#     977         self.components_ = U
#     978         self.error_ = E
#
# /usr/lib/pymodules/python2.7/sklearn/decomposition/dict_learning.pyc in dict_learning(X, n_atoms, alpha, max_iter, tol, method, n_jobs, dict_init, code_init, callback, verbose, random_state)
#     497         dictionary, residuals = _update_dict(dictionary.T, X.T, code.T,
#     498                                              verbose=verbose, return_r2=True,
# --> 499                                              random_state=random_state)
#     500         dictionary = dictionary.T
#     501
#
# /usr/lib/pymodules/python2.7/sklearn/decomposition/dict_learning.pyc in _update_dict(dictionary, Y, code, verbose, return_r2, random_state)
#     353             dictionary[:, k] /= sqrt(atom_norm_square)
#     354             # R <- -1.0 * U_k * V_k^T + R
# --> 355             R = ger(-1.0, dictionary[:, k], code[k, :], a=R, overwrite_a=True)
#     356     if return_r2:
#     357         R **= 2
#
# KeyboardInterrupt:

# %%
house = 20
disag = disaggregate(sparse_coder, pecan_sets[house]['use'])

from matplotlib import rcParams
rcParams['figure.figsize'] = (15,10)
import matplotlib.pyplot as plt

pd.DataFrame({
        'actual': pecan_sets[house]['use'],
        'disag': disag['use']}).plot()

fig, axes = plt.subplots(nrows=3, ncols=3)
for i,category in enumerate(categories):
    pd.DataFrame({
        'actual': pecan_sets[house][category],
        'disag': disag[category]}).plot(ax=axes[i/3,i%3])
    axes[i/3,i%3].set_title(category)
