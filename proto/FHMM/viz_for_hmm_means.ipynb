# %%
import sys
sys.path.append('../../') # or non-Unix equivalent (add wikienergy/ to path)
from collections import OrderedDict
import itertools
import numpy as np
from sklearn import hmm
import matplotlib.pyplot as plt
import matplotlib.cm as cm
# %matplotlib inline
import pylab
from pylab import plot, show, title, xlabel, ylabel, subplot
pylab.rcParams['figure.figsize'] = 12,9

# %%
import pickle
with open('../../data/may_air.pkl','rb') as f:
   devices_models['air1']=pickle.load(f)

# %%
with open('may_air.pkl','w') as f:
    pickle.dump(devices_models['air1'],f)

# %%
# Out:
# OrderedDict([(26, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (59, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (86, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (93, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (94, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (280, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (410, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (434, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (484, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (499, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (580, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (624, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (661, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (739, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (744, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (774, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (821, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (871, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (936, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (1086, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (1167, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (1283, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (1334, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (1450, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (1507, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (1617, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (1632, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (1681, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (1696, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (1714, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (1718, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (1782, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (1790, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (1830, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (1953, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (1994, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (2034, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (2094, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (2129, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (2156, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (2158, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (2171, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (2242, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (2365, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (2378, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (2470, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (2575, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (2606, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (2638, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (2641, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (2769, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (2787, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (2814, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (2829, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (2845, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (2864, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (2945, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (2953, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (2974, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (3044, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (3092, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (3134, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (3192, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (3221, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (3263, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (3367, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (3394, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (3456, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (3482, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (3504, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (3531, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (3649, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (3652, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (3723, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (3736, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (3778, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (3795, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (3893, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (4135, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (4154, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (4298, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (4313, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (4352, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (4373, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (4505, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (4526, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (4641, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (4767, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (4874, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (4922, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (4956, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (4957, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (4998, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (5026, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (5109, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (5209, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (5218, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (5275, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (5357, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (5395, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (5545, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (5568, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (5677, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (5785, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (5814, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (5852, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (5874, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (5889, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (5938, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (5949, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
# ...
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (8419, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (8645, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (8669, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (8741, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (8956, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9019, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9036, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9121, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9141, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9160, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9343, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9356, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9484, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9488, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9499, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9555, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9578, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9609, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9613, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9643, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9654, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9701, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9729, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9737, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9771, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9830, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9875, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9915, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9922, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9926, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9932, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9934, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9938, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9939, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9982, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None)), (9983, GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#       covars_weight=1,
#       init_params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       means_prior=None, means_weight=0, n_components=3, n_iter=10,
#       params='abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ',
#       random_state=None, startprob=None, startprob_prior=None, thresh=0.01,
#       transmat=None, transmat_prior=None))])

# %%
#startprob_
#means_
#transmat_
#covars_
state_0=[]
state_1=[]
state_2=[]
for model_num in devices_models['air1']:
    a=devices_models['air1'][model_num].means_
    state_0.append(a[0][0])
    state_1.append(a[1][0])
    state_2.append(a[2][0])
high_lim=10
bins=30
plt.subplot(3,1,1)
plt.hist(state_0,bins,range=[0,high_lim])
plt.xlim([0 ,high_lim])
plt.subplot(3,1,2)
plt.hist(state_1,bins,range=[0,high_lim])
plt.xlim([0 ,high_lim])
plt.subplot(3,1,3)
plt.hist(state_2,bins,range=[0,high_lim])
plt.xlim([0 ,high_lim])
# Out:
# (0, 10)

# %%
"""
Show how to modify the coordinate formatter to report the image "z"
value of the nearest pixel given x and y
"""

def format_coord(x, y):
    col = int(x+0.5)
    row = int(y+0.5)
    if col>=0 and col<numcols and row>=0 and row<numrows:
        z = X[row,col]
        return 'x=%1.4f, y=%1.4f, z=%1.4f'%(x, y, z)
    else:
        return 'x=%1.4f, y=%1.4f'%(x, y)

# %%
X = 10*np.random.rand(5,3)
a=[]
for model_num in devices_models['air1']:
    a.extend(np.array([devices_models['air1'][model_num].means_[0],devices_models['air1'][model_num].means_[1],devices_models['air1'][model_num].means_[2]]).T)


a=np.array(a).T
idx = np.argsort(a[2])   
c = a.copy()
for i in range(len(idx)):
  a[:,i] = c[:,idx[i]]
    
pylab.rcParams['figure.figsize'] = 10, 10
fig, ax = plt.subplots()
ax.imshow(a, cmap='Blues', interpolation='nearest',aspect='auto')


plt.show()
